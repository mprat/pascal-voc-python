# %%
import os
import pandas as pd
from bs4 import BeautifulSoup
import voc_utils
from more_itertools import unique_everseen

# %%
root_dir = '/Users/mprat/personal/VOCdevkit/VOC2012/'
img_dir = os.path.join(root_dir, 'JPEGImages')
ann_dir = os.path.join(root_dir, 'Annotations')
set_dir = os.path.join(root_dir, 'ImageSets', 'Main')

# %%
# list image sets
all_files = !ls {set_dir}
image_sets = sorted(list(set([filename.replace('.txt', '').strip().split('_')[0] for filename in all_files])))
print image_sets
# Out:
# ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'trainval', 'tvmonitor', 'val']

# %%
# category name is from above, dataset is either "train" or
# "val" or "train_val"
def imgs_from_category(cat_name, dataset):
    filename = os.path.join(set_dir, cat_name + "_" + dataset + ".txt")
    df = pd.read_csv(
        filename,
        delim_whitespace=True,
        header=None,
        names=['filename', 'true'])
    return df

def imgs_from_category_as_list(cat_name, dataset):
    df = imgs_from_category(cat_name, dataset)
    df = df[df['true'] == 1]
    return df['filename'].values

def annotation_file_from_img(img_name):
    return os.path.join(ann_dir, img_name) + '.xml'

# %%
# annotation operations
def load_annotation(img_filename):
    xml = ""
    with open(annotation_file_from_img(img_filename)) as f:
        xml = f.readlines()
    xml = ''.join([line.strip('\t') for line in xml])
    return BeautifulSoup(xml)

def get_all_obj_and_box(objname, img_set):
    img_list = imgs_from_category_as_list(objname, img_set)
    
    for img in img_list:
        annotation = load_annotation(img)

# %%
# image operations
def load_img(img_filename):
    return io.load_image(os.path.join(img_dir, img_filename + '.jpg'))

# %%
train_img_list = imgs_from_category_as_list('bicycle', 'train')

# %%
a = load_annotation(train_img_list[0])

# %%
def load_train_data(category):
    to_find = category
    train_filename = '/Users/mprat/personal/VOCdevkit/VOC2012/csvs/train_' + category + '.csv'
    if os.path.isfile(train_filename):
        return pd.read_csv(train_filename)
    else:
        train_img_list = imgs_from_category_as_list(to_find, 'train')
        data = []
        for item in train_img_list:
            anno = load_annotation(item)
            objs = anno.findAll('object')
            for obj in objs:
                obj_names = obj.findChildren('name')
                for name_tag in obj_names:
                    if str(name_tag.contents[0]) == 'bicycle':
                        fname = anno.findChild('filename').contents[0]
                        bbox = obj.findChildren('bndbox')[0]
                        xmin = int(bbox.findChildren('xmin')[0].contents[0])
                        ymin = int(bbox.findChildren('ymin')[0].contents[0])
                        xmax = int(bbox.findChildren('xmax')[0].contents[0])
                        ymax = int(bbox.findChildren('ymax')[0].contents[0])
                        data.append([fname, xmin, ymin, xmax, ymax])
        df = pd.DataFrame(data, columns=['fname', 'xmin', 'ymin', 'xmax', 'ymax'])
        df.to_csv(train_filename, index=False)
        return df

# %%
df = load_train_data('bicycle')
print list(unique_everseen(list(voc_utils.img_dir + df['fname'])))
# Out:
# ['/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_000036.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_000191.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_000196.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_000531.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_000615.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_000764.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001336.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001375.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001402.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001523.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001566.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001626.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001791.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001813.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001860.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_001986.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002129.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002204.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002370.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002418.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002515.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002679.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002787.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002880.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002894.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_002948.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_003075.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_003140.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_003329.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_003617.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_003682.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_003819.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_004113.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_004163.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_004280.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_004325.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_004331.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_004441.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_004574.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_004603.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005055.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005201.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005412.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005484.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005650.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005713.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005737.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005839.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005921.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_005982.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_006064.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_006195.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_006234.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_006253.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_006257.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_006361.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_006410.jpg', '/Users/mprat/personal/VOCdevkit/VOC2012/JPEGImages2008_006579.jpg ...

# %%
for cat in image_sets:
    if cat != 'train' and cat != 'val' and cat != 'trainval':
        load_train_data(cat)

# %%
df = load_train_data('bicycle')
for row_num, entry in df.iterrows():
    print entry
print df
# Out:
# fname    2008_000036.jpg
# xmin                 120
# ymin                   1
# xmax                 203
# ymax                  35
# Name: 0, dtype: object
# fname    2008_000036.jpg
# xmin                 117
# ymin                  38
# xmax                 273
# ymax                 121
# Name: 1, dtype: object
# fname    2008_000191.jpg
# xmin                  57
# ymin                 194
# xmax                 151
# ymax                 255
# Name: 2, dtype: object
# fname    2008_000196.jpg
# xmin                 348
# ymin                   7
# xmax                 500
# ymax                 309
# Name: 3, dtype: object
# fname    2008_000196.jpg
# xmin                   1
# ymin                   1
# xmax                 206
# ymax                 310
# Name: 4, dtype: object
# fname    2008_000531.jpg
# xmin                  99
# ymin                 183
# xmax                 203
# ymax                 263
# Name: 5, dtype: object
# fname    2008_000615.jpg
# xmin                  50
# ymin                 179
# xmax                 311
# ymax                 375
# Name: 6, dtype: object
# fname    2008_000764.jpg
# xmin                  39
# ymin                 331
# xmax                 243
# ymax                 487
# Name: 7, dtype: object
# fname    2008_001336.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 372
# Name: 8, dtype: object
# fname    2008_001375.jpg
# xmin                 275
# ymin                 249
# xmax                 500
# ymax                 333
# Name: 9, dtype: object
# fname    2008_001375.jpg
# xmin                   1
# ymin                 290
# xmax                 198
# ymax                 333
# Name: 10, dtype: object
# fname    2008_001402.jpg
# xmin                 115
# ymin                 279
# xmax                 243
# ymax                 482
# Name: 11, dtype: object
# fname    2008_001523.jpg
# xmin                 115
# ymin                 244
# xmax                 214
# ymax                 349
# Name: 12, dtype: object
# fname    2008_001566.jpg
# xmin                   1
# ymin                 190
# xmax                 149
# ymax                 300
# Name: 13, dtype: object
# fname    2008_001626.jpg
# xmin                  20
# ymin                  11
# xmax                 439
# ymax                 375
# Name: 14, dtype: object
# fname    2008_001791.jpg
# xmin                  45
# ymin                 393
# xmax                 112
# ymax                 500
# Name: 15, dtype: object
# fname    2008_001813.jpg
# xmin                   1
# ymin                  35
# xmax                 334
# ymax                 500
# Name: 16, dtype: object
# fname    2008_001860.jpg
# xmin                   1
# ymin                 201
# xmax                 151
# ymax                 333
# Name: 17, dtype: object
# fname    2008_001986.jpg
# xmin                  49
# ymin                 241
# xmax                 286
# ymax                 379
# Name: 18, dtype: object
# fname    2008_002129.jpg
# xmin                   6
# ymin                   1
# xmax                 432
# ymax                 319
# Name: 19, dtype: object
# fname    2008_002204.jpg
# xmin                 117
# ymin                 243
# xmax                 247
# ymax                 322
# Name: 20, dtype: object
# fname    2008_002370.jpg
# xmin                   1
# ymin                   1
# xmax                  81
# ymax                 240
# Name: 21, dtype: object
# fname    2008_002418.jpg
# xmin                  40
# ymin                 201
# xmax                 309
# ymax                 475
# Name: 22, dtype: object
# fname    2008_002515.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 334
# Name: 23, dtype: object
# fname    2008_002679.jpg
# xmin                  94
# ymin                 103
# xmax                 239
# ymax                 306
# Name: 24, dtype: object
# fname    2008_002787.jpg
# xmin                  35
# ymin                 170
# xmax                 231
# ymax                 375
# Name: 25, dtype: object
# fname    2008_002787.jpg
# xmin                 296
# ymin                 176
# xmax                 500
# ymax                 375
# Name: 26, dtype: object
# fname    2008_002880.jpg
# xmin                 151
# ymin                 245
# xmax                 254
# ymax                 301
# Name: 27, dtype: object
# fname    2008_002894.jpg
# xmin                  43
# ymin                 154
# xmax                 388
# ymax                 332
# Name: 28, dtype: object
# fname    2008_002948.jpg
# xmin                   9
# ymin                   1
# xmax                 169
# ymax                 333
# Name: 29, dtype: object
# fname    2008_002948.jpg
# xmin                   1
# ymin                   1
# xmax                 135
# ymax                 306
# Name: 30, dtype: object
# fname    2008_003075.jpg
# xmin                 253
# ymin                   1
# xmax                 478
# ymax                 203
# Name: 31, dtype: object
# fname    2008_003140.jpg
# xmin                  62
# ymin                 239
# xmax                 417
# ymax                 375
# Name: 32, dtype: object
# fname    2008_003140.jpg
# xmin                   1
# ymin                 217
# xmax                 276
# ymax                 375
# Name: 33, dtype: object
# fname    2008_003329.jpg
# xmin                 237
# ymin                 301
# xmax                 427
# ymax                 375
# Name: 34, dtype: object
# fname    2008_003329.jpg
# xmin                 424
# ymin                 296
# xmax                 500
# ymax                 375
# Name: 35, dtype: object
# fname    2008_003329.jpg
# xmin                 229
# ymin                 183
# xmax                 277
# ymax                 280
# Name: 36, dtype: object
# fname    2008_003329.jpg
# xmin                 153
# ymin                 155
# xmax                 186
# ymax                 217
# Name: 37, dtype: object
# fname    2008_003617.jpg
# xmin                   1
# ymin                 295
# xmax                  79
# ymax                 394
# Name: 38, dtype: object
# fname    2008_003682.jpg
# xmin                 350
# ymin                  50
# xmax                 361
# ymax                  76
# Name: 39, dtype: object
# fname    2008_003682.jpg
# xmin                 431
# ymin                  54
# xmax                 443
# ymax                  86
# Name: 40, dtype: object
# fname    2008_003682.jpg
# xmin                 255
# ymin                 163
# xmax                 399
# ymax                 333
# Name: 41, dtype: object
# fname    2008_003682.jpg
# xmin                   1
# ymin                 226
# xmax                  56
# ymax                 333
# Name: 42, dtype: object
# fname    2008_003682.jpg
# xmin                   1
# ymin                 201
# xmax                  82
# ymax                 333
# Name: 43, dtype: object
# fname    2008_003819.jpg
# xmin                 293
# ymin                 186
# xmax                 422
# ymax                 261
# Name: 44, dtype: object
# fname    2008_003819.jpg
# xmin                 146
# ymin                 187
# xmax                 242
# ymax                 254
# Name: 45, dtype: object
# fname    2008_003819.jpg
# xmin                  65
# ymin                 187
# xmax                 137
# ymax                 244
# Name: 46, dtype: object
# fname    2008_003819.jpg
# xmin                   1
# ymin                 189
# xmax                  48
# ymax                 242
# Name: 47, dtype: object
# fname    2008_004113.jpg
# xmin                 281
# ymin                 205
# xmax                 309
# ymax                 258
# Name: 48, dtype: object
# fname    2008_004113.jpg
# xmin                 232
# ymin                 209
# xmax                 259
# ymax                 260
# Name: 49, dtype: object
# fname    2008_004113.jpg
# xmin                 265
# ymin                 191
# xmax                 276
# ymax                 216
# Name: 50, dtype: object
# fname    2008_004163.jpg
# xmin                   1
# ymin                 350
# xmax                  54
# ymax                 439
# Name: 51, dtype: object
# fname    2008_004280.jpg
# xmin                  17
# ymin                  17
# xmax                 500
# ymax                 342
# Name: 52, dtype: object
# fname    2008_004325.jpg
# xmin                 101
# ymin                 308
# xmax                 295
# ymax                 424
# Name: 53, dtype: object
# fname    2008_004331.jpg
# xmin                 117
# ymin                 195
# xmax                 375
# ymax                 500
# Name: 54, dtype: object
# fname    2008_004441.jpg
# xmin                   1
# ymin                   1
# xmax                 356
# ymax                 233
# Name: 55, dtype: object
# fname    2008_004574.jpg
# xmin                 104
# ymin                   1
# xmax                 223
# ymax                  97
# Name: 56, dtype: object
# fname    2008_004574.jpg
# xmin                 174
# ymin                   2
# xmax                 287
# ymax                  99
# Name: 57, dtype: object
# fname    2008_004574.jpg
# xmin                 190
# ymin                 284
# xmax                 472
# ymax                 375
# Name: 58, dtype: object
# fname    2008_004603.jpg
# xmin                  10
# ymin                 154
# xmax                 406
# ymax                 315
# Name: 59, dtype: object
# fname    2008_004603.jpg
# xmin                   1
# ymin                 101
# xmax                 104
# ymax                 243
# Name: 60, dtype: object
# fname    2008_005055.jpg
# xmin                 108
# ymin                 212
# xmax                 159
# ymax                 289
# Name: 61, dtype: object
# fname    2008_005055.jpg
# xmin                 186
# ymin                 160
# xmax                 220
# ymax                 209
# Name: 62, dtype: object
# fname    2008_005055.jpg
# xmin                 102
# ymin                 147
# xmax                 119
# ymax                 169
# Name: 63, dtype: object
# fname    2008_005201.jpg
# xmin                   1
# ymin                 128
# xmax                 162
# ymax                 281
# Name: 64, dtype: object
# fname    2008_005201.jpg
# xmin                 116
# ymin                  95
# xmax                 371
# ymax                 319
# Name: 65, dtype: object
# fname    2008_005201.jpg
# xmin                 252
# ymin                 108
# xmax                 472
# ymax                 359
# Name: 66, dtype: object
# fname    2008_005412.jpg
# xmin                  49
# ymin                 114
# xmax                 367
# ymax                 359
# Name: 67, dtype: object
# fname    2008_005484.jpg
# xmin                  80
# ymin                 248
# xmax                 332
# ymax                 375
# Name: 68, dtype: object
# fname    2008_005650.jpg
# xmin                 282
# ymin                 211
# xmax                 345
# ymax                 322
# Name: 69, dtype: object
# fname    2008_005650.jpg
# xmin                 177
# ymin                 256
# xmax                 243
# ymax                 368
# Name: 70, dtype: object
# fname    2008_005650.jpg
# xmin                 125
# ymin                 227
# xmax                 176
# ymax                 334
# Name: 71, dtype: object
# fname    2008_005650.jpg
# xmin                 450
# ymin                 142
# xmax                 475
# ymax                 179
# Name: 72, dtype: object
# fname    2008_005650.jpg
# xmin                 347
# ymin                 131
# xmax                 359
# ymax                 152
# Name: 73, dtype: object
# fname    2008_005650.jpg
# xmin                 165
# ymin                 109
# xmax                 174
# ymax                 126
# Name: 74, dtype: object
# fname    2008_005650.jpg
# xmin                 206
# ymin                 109
# xmax                 231
# ymax                 124
# Name: 75, dtype: object
# fname    2008_005650.jpg
# xmin                 302
# ymin                 114
# xmax                 315
# ymax                 137
# Name: 76, dtype: object
# fname    2008_005713.jpg
# xmin                  58
# ymin                  99
# xmax                 382
# ymax                 308
# Name: 77, dtype: object
# fname    2008_005737.jpg
# xmin                 117
# ymin                 310
# xmax                 240
# ymax                 500
# Name: 78, dtype: object
# fname    2008_005737.jpg
# xmin                  54
# ymin                 253
# xmax                 112
# ymax                 345
# Name: 79, dtype: object
# fname    2008_005737.jpg
# xmin                   1
# ymin                 332
# xmax                  91
# ymax                 500
# Name: 80, dtype: object
# fname    2008_005839.jpg
# xmin                 201
# ymin                 297
# xmax                 383
# ymax                 375
# Name: 81, dtype: object
# fname    2008_005839.jpg
# xmin                   1
# ymin                 270
# xmax                 189
# ymax                 375
# Name: 82, dtype: object
# fname    2008_005921.jpg
# xmin                  53
# ymin                 199
# xmax                 341
# ymax                 388
# Name: 83, dtype: object
# fname    2008_005921.jpg
# xmin                 197
# ymin                 217
# xmax                 418
# ymax                 356
# Name: 84, dtype: object
# fname    2008_005982.jpg
# xmin                  11
# ymin                  16
# xmax                 491
# ymax                 315
# Name: 85, dtype: object
# fname    2008_006064.jpg
# xmin                  64
# ymin                 274
# xmax                 275
# ymax                 359
# Name: 86, dtype: object
# fname    2008_006195.jpg
# xmin                 146
# ymin                 177
# xmax                 237
# ymax                 353
# Name: 87, dtype: object
# fname    2008_006234.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 395
# Name: 88, dtype: object
# fname    2008_006253.jpg
# xmin                 102
# ymin                 200
# xmax                 383
# ymax                 478
# Name: 89, dtype: object
# fname    2008_006257.jpg
# xmin                 166
# ymin                 207
# xmax                 290
# ymax                 443
# Name: 90, dtype: object
# fname    2008_006361.jpg
# xmin                  52
# ymin                   1
# xmax                 345
# ymax                 479
# Name: 91, dtype: object
# fname    2008_006410.jpg
# xmin                  57
# ymin                 263
# xmax                 266
# ymax                 464
# Name: 92, dtype: object
# fname    2008_006579.jpg
# xmin                  16
# ymin                  27
# xmax                 480
# ymax                 353
# Name: 93, dtype: object
# fname    2008_006645.jpg
# xmin                  54
# ymin                  82
# xmax                 500
# ymax                 375
# Name: 94, dtype: object
# fname    2008_006807.jpg
# xmin                   1
# ymin                 229
# xmax                 109
# ymax                 375
# Name: 95, dtype: object
# fname    2008_006807.jpg
# xmin                 317
# ymin                 288
# xmax                 416
# ymax                 375
# Name: 96, dtype: object
# fname    2008_007179.jpg
# xmin                  84
# ymin                 211
# xmax                 148
# ymax                 260
# Name: 97, dtype: object
# fname    2008_007265.jpg
# xmin                   2
# ymin                  76
# xmax                 313
# ymax                 452
# Name: 98, dtype: object
# fname    2008_007410.jpg
# xmin                 100
# ymin                 191
# xmax                 347
# ymax                 346
# Name: 99, dtype: object
# fname    2008_007421.jpg
# xmin                  41
# ymin                 147
# xmax                 213
# ymax                 293
# Name: 100, dtype: object
# fname    2008_007470.jpg
# xmin                 229
# ymin                 104
# xmax                 371
# ymax                 237
# Name: 101, dtype: object
# fname    2008_007510.jpg
# xmin                  84
# ymin                 233
# xmax                 139
# ymax                 332
# Name: 102, dtype: object
# fname    2008_007510.jpg
# xmin                  27
# ymin                 229
# xmax                  73
# ymax                 317
# Name: 103, dtype: object
# fname    2008_007510.jpg
# xmin                   1
# ymin                 232
# xmax                  40
# ymax                 305
# Name: 104, dtype: object
# fname    2008_007761.jpg
# xmin                   1
# ymin                  79
# xmax                  62
# ymax                 134
# Name: 105, dtype: object
# fname    2008_007761.jpg
# xmin                 255
# ymin                 143
# xmax                 317
# ymax                 324
# Name: 106, dtype: object
# fname    2008_007833.jpg
# xmin                 297
# ymin                 287
# xmax                 500
# ymax                 375
# Name: 107, dtype: object
# fname    2008_007861.jpg
# xmin                  99
# ymin                 164
# xmax                 240
# ymax                 363
# Name: 108, dtype: object
# fname    2008_007882.jpg
# xmin                 265
# ymin                 351
# xmax                 375
# ymax                 460
# Name: 109, dtype: object
# fname    2008_008021.jpg
# xmin                 225
# ymin                 187
# xmax                 267
# ymax                 237
# Name: 110, dtype: object
# fname    2008_008064.jpg
# xmin                 119
# ymin                 209
# xmax                 310
# ymax                 375
# Name: 111, dtype: object
# fname    2008_008064.jpg
# xmin                   1
# ymin                 241
# xmax                  74
# ymax                 375
# Name: 112, dtype: object
# fname    2008_008080.jpg
# xmin                  56
# ymin                 235
# xmax                 486
# ymax                 440
# Name: 113, dtype: object
# fname    2008_008092.jpg
# xmin                 251
# ymin                 228
# xmax                 289
# ymax                 264
# Name: 114, dtype: object
# fname    2008_008095.jpg
# xmin                 286
# ymin                 131
# xmax                 423
# ymax                 309
# Name: 115, dtype: object
# fname    2008_008095.jpg
# xmin                 106
# ymin                 200
# xmax                 159
# ymax                 267
# Name: 116, dtype: object
# fname    2008_008095.jpg
# xmin                   1
# ymin                 142
# xmax                  92
# ymax                 302
# Name: 117, dtype: object
# fname    2008_008097.jpg
# xmin                 163
# ymin                 180
# xmax                 374
# ymax                 288
# Name: 118, dtype: object
# fname    2008_008112.jpg
# xmin                 131
# ymin                 100
# xmax                 472
# ymax                 333
# Name: 119, dtype: object
# fname    2008_008315.jpg
# xmin                 198
# ymin                 208
# xmax                 312
# ymax                 340
# Name: 120, dtype: object
# fname    2008_008325.jpg
# xmin                   1
# ymin                 327
# xmax                 333
# ymax                 500
# Name: 121, dtype: object
# fname    2008_008325.jpg
# xmin                 266
# ymin                 238
# xmax                 333
# ymax                 322
# Name: 122, dtype: object
# fname    2008_008368.jpg
# xmin                   1
# ymin                   2
# xmax                 500
# ymax                 375
# Name: 123, dtype: object
# fname    2008_008480.jpg
# xmin                 111
# ymin                 195
# xmax                 139
# ymax                 222
# Name: 124, dtype: object
# fname    2008_008528.jpg
# xmin                 234
# ymin                 173
# xmax                 352
# ymax                 251
# Name: 125, dtype: object
# fname    2008_008528.jpg
# xmin                  69
# ymin                 193
# xmax                 209
# ymax                 270
# Name: 126, dtype: object
# fname    2008_008528.jpg
# xmin                  11
# ymin                 214
# xmax                 129
# ymax                 270
# Name: 127, dtype: object
# fname    2008_008528.jpg
# xmin                   1
# ymin                 154
# xmax                  36
# ymax                 200
# Name: 128, dtype: object
# fname    2008_008530.jpg
# xmin                 123
# ymin                 112
# xmax                 310
# ymax                 250
# Name: 129, dtype: object
# fname    2008_008572.jpg
# xmin                 152
# ymin                 161
# xmax                 224
# ymax                 262
# Name: 130, dtype: object
# fname    2008_008579.jpg
# xmin                 147
# ymin                 139
# xmax                 284
# ymax                 235
# Name: 131, dtype: object
# fname    2008_008579.jpg
# xmin                 325
# ymin                 121
# xmax                 436
# ymax                 205
# Name: 132, dtype: object
# fname    2008_008579.jpg
# xmin                 471
# ymin                 106
# xmax                 500
# ymax                 199
# Name: 133, dtype: object
# fname    2008_008591.jpg
# xmin                 187
# ymin                 145
# xmax                 328
# ymax                 316
# Name: 134, dtype: object
# fname    2008_008671.jpg
# xmin                  56
# ymin                  46
# xmax                 420
# ymax                 375
# Name: 135, dtype: object
# fname    2008_008691.jpg
# xmin                 388
# ymin                 201
# xmax                 500
# ymax                 299
# Name: 136, dtype: object
# fname    2008_008691.jpg
# xmin                 141
# ymin                 258
# xmax                 382
# ymax                 375
# Name: 137, dtype: object
# fname    2008_008691.jpg
# xmin                   1
# ymin                 224
# xmax                 120
# ymax                 320
# Name: 138, dtype: object
# fname    2008_008691.jpg
# xmin                   1
# ymin                 227
# xmax                 113
# ymax                 315
# Name: 139, dtype: object
# fname    2008_008707.jpg
# xmin                   1
# ymin                 184
# xmax                  65
# ymax                 265
# Name: 140, dtype: object
# fname    2008_008707.jpg
# xmin                  64
# ymin                 178
# xmax                 173
# ymax                 258
# Name: 141, dtype: object
# fname    2008_008707.jpg
# xmin                 163
# ymin                 182
# xmax                 268
# ymax                 257
# Name: 142, dtype: object
# fname    2008_008707.jpg
# xmin                 293
# ymin                 182
# xmax                 370
# ymax                 254
# Name: 143, dtype: object
# fname    2008_008707.jpg
# xmin                 369
# ymin                 184
# xmax                 455
# ymax                 252
# Name: 144, dtype: object
# fname    2008_008707.jpg
# xmin                 474
# ymin                 183
# xmax                 500
# ymax                 250
# Name: 145, dtype: object
# fname    2008_008717.jpg
# xmin                  98
# ymin                 158
# xmax                 232
# ymax                 404
# Name: 146, dtype: object
# fname    2008_008717.jpg
# xmin                 256
# ymin                 160
# xmax                 324
# ymax                 200
# Name: 147, dtype: object
# fname    2008_008725.jpg
# xmin                 347
# ymin                 178
# xmax                 399
# ymax                 245
# Name: 148, dtype: object
# fname    2008_008745.jpg
# xmin                 384
# ymin                 145
# xmax                 500
# ymax                 260
# Name: 149, dtype: object
# fname    2008_008745.jpg
# xmin                 328
# ymin                 272
# xmax                 500
# ymax                 371
# Name: 150, dtype: object
# fname    2009_000015.jpg
# xmin                  96
# ymin                 174
# xmax                 203
# ymax                 345
# Name: 151, dtype: object
# fname    2009_000105.jpg
# xmin                 465
# ymin                 178
# xmax                 500
# ymax                 212
# Name: 152, dtype: object
# fname    2009_000105.jpg
# xmin                 475
# ymin                 181
# xmax                 500
# ymax                 216
# Name: 153, dtype: object
# fname    2009_000161.jpg
# xmin                  47
# ymin                 118
# xmax                 211
# ymax                 370
# Name: 154, dtype: object
# fname    2009_000195.jpg
# xmin                 123
# ymin                   1
# xmax                 370
# ymax                 370
# Name: 155, dtype: object
# fname    2009_000197.jpg
# xmin                 418
# ymin                 155
# xmax                 465
# ymax                 171
# Name: 156, dtype: object
# fname    2009_000197.jpg
# xmin                 376
# ymin                 162
# xmax                 431
# ymax                 183
# Name: 157, dtype: object
# fname    2009_000237.jpg
# xmin                 207
# ymin                 202
# xmax                 471
# ymax                 375
# Name: 158, dtype: object
# fname    2009_000237.jpg
# xmin                  85
# ymin                 174
# xmax                 137
# ymax                 272
# Name: 159, dtype: object
# fname    2009_000237.jpg
# xmin                 131
# ymin                 159
# xmax                 157
# ymax                 228
# Name: 160, dtype: object
# fname    2009_000281.jpg
# xmin                  64
# ymin                  21
# xmax                 444
# ymax                 314
# Name: 161, dtype: object
# fname    2009_000281.jpg
# xmin                   1
# ymin                  34
# xmax                 186
# ymax                 200
# Name: 162, dtype: object
# fname    2009_000344.jpg
# xmin                  64
# ymin                   4
# xmax                 440
# ymax                 348
# Name: 163, dtype: object
# fname    2009_000445.jpg
# xmin                  68
# ymin                  17
# xmax                 458
# ymax                 315
# Name: 164, dtype: object
# fname    2009_000696.jpg
# xmin                   1
# ymin                   1
# xmax                 375
# ymax                 500
# Name: 165, dtype: object
# fname    2009_000757.jpg
# xmin                  14
# ymin                 112
# xmax                 263
# ymax                 278
# Name: 166, dtype: object
# fname    2009_000805.jpg
# xmin                   1
# ymin                   1
# xmax                 482
# ymax                 375
# Name: 167, dtype: object
# fname    2009_000882.jpg
# xmin                 386
# ymin                 163
# xmax                 490
# ymax                 234
# Name: 168, dtype: object
# fname    2009_000975.jpg
# xmin                 332
# ymin                 232
# xmax                 441
# ymax                 301
# Name: 169, dtype: object
# fname    2009_000975.jpg
# xmin                 260
# ymin                 227
# xmax                 313
# ymax                 304
# Name: 170, dtype: object
# fname    2009_001074.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 375
# Name: 171, dtype: object
# fname    2009_001096.jpg
# xmin                   1
# ymin                 200
# xmax                 326
# ymax                 375
# Name: 172, dtype: object
# fname    2009_001364.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 325
# Name: 173, dtype: object
# fname    2009_001480.jpg
# xmin                   1
# ymin                 261
# xmax                 362
# ymax                 500
# Name: 174, dtype: object
# fname    2009_001481.jpg
# xmin                  37
# ymin                  70
# xmax                 356
# ymax                 296
# Name: 175, dtype: object
# fname    2009_001558.jpg
# xmin                  96
# ymin                   1
# xmax                 311
# ymax                 500
# Name: 176, dtype: object
# fname    2009_001642.jpg
# xmin                   7
# ymin                 134
# xmax                 417
# ymax                 378
# Name: 177, dtype: object
# fname    2009_001642.jpg
# xmin                 277
# ymin                 146
# xmax                 455
# ymax                 280
# Name: 178, dtype: object
# fname    2009_001695.jpg
# xmin                   1
# ymin                 295
# xmax                 331
# ymax                 500
# Name: 179, dtype: object
# fname    2009_001704.jpg
# xmin                  38
# ymin                  45
# xmax                 500
# ymax                 367
# Name: 180, dtype: object
# fname    2009_001840.jpg
# xmin                  53
# ymin                  33
# xmax                 485
# ymax                 342
# Name: 181, dtype: object
# fname    2009_001926.jpg
# xmin                   1
# ymin                  22
# xmax                 500
# ymax                 375
# Name: 182, dtype: object
# fname    2009_001997.jpg
# xmin                  14
# ymin                 227
# xmax                  26
# ymax                 247
# Name: 183, dtype: object
# fname    2009_002119.jpg
# xmin                  37
# ymin                  29
# xmax                 451
# ymax                 268
# Name: 184, dtype: object
# fname    2009_002145.jpg
# xmin                 217
# ymin                 224
# xmax                 383
# ymax                 375
# Name: 185, dtype: object
# fname    2009_002203.jpg
# xmin                 372
# ymin                 213
# xmax                 395
# ymax                 243
# Name: 186, dtype: object
# fname    2009_002271.jpg
# xmin                  93
# ymin                 174
# xmax                 300
# ymax                 310
# Name: 187, dtype: object
# fname    2009_002338.jpg
# xmin                   1
# ymin                 250
# xmax                 146
# ymax                 334
# Name: 188, dtype: object
# fname    2009_002338.jpg
# xmin                  90
# ymin                 225
# xmax                 369
# ymax                 334
# Name: 189, dtype: object
# fname    2009_002338.jpg
# xmin                 194
# ymin                 258
# xmax                 493
# ymax                 334
# Name: 190, dtype: object
# fname    2009_002371.jpg
# xmin                  58
# ymin                  53
# xmax                 438
# ymax                 317
# Name: 191, dtype: object
# fname    2009_002404.jpg
# xmin                 276
# ymin                  30
# xmax                 396
# ymax                 148
# Name: 192, dtype: object
# fname    2009_002404.jpg
# xmin                 297
# ymin                 295
# xmax                 393
# ymax                 333
# Name: 193, dtype: object
# fname    2009_002406.jpg
# xmin                   1
# ymin                 209
# xmax                 273
# ymax                 500
# Name: 194, dtype: object
# fname    2009_002438.jpg
# xmin                  26
# ymin                  41
# xmax                 480
# ymax                 359
# Name: 195, dtype: object
# fname    2009_002519.jpg
# xmin                 372
# ymin                 168
# xmax                 455
# ymax                 300
# Name: 196, dtype: object
# fname    2009_002542.jpg
# xmin                   1
# ymin                 152
# xmax                  54
# ymax                 217
# Name: 197, dtype: object
# fname    2009_002671.jpg
# xmin                 248
# ymin                 119
# xmax                 418
# ymax                 199
# Name: 198, dtype: object
# fname    2009_002715.jpg
# xmin                 245
# ymin                 427
# xmax                 334
# ymax                 500
# Name: 199, dtype: object
# fname    2009_002764.jpg
# xmin                  39
# ymin                  45
# xmax                 483
# ymax                 307
# Name: 200, dtype: object
# fname    2009_002780.jpg
# xmin                  60
# ymin                  37
# xmax                 480
# ymax                 333
# Name: 201, dtype: object
# fname    2009_002835.jpg
# xmin                  12
# ymin                  30
# xmax                 500
# ymax                 356
# Name: 202, dtype: object
# fname    2009_002853.jpg
# xmin                 414
# ymin                 238
# xmax                 463
# ymax                 273
# Name: 203, dtype: object
# fname    2009_002983.jpg
# xmin                  11
# ymin                 263
# xmax                 171
# ymax                 366
# Name: 204, dtype: object
# fname    2009_002983.jpg
# xmin                  95
# ymin                 177
# xmax                 162
# ymax                 256
# Name: 205, dtype: object
# fname    2009_002983.jpg
# xmin                 146
# ymin                  74
# xmax                 180
# ymax                  93
# Name: 206, dtype: object
# fname    2009_002983.jpg
# xmin                  93
# ymin                  75
# xmax                 132
# ymax                  97
# Name: 207, dtype: object
# fname    2009_003007.jpg
# xmin                 113
# ymin                  47
# xmax                 222
# ymax                 474
# Name: 208, dtype: object
# fname    2009_003042.jpg
# xmin                 195
# ymin                 174
# xmax                 259
# ymax                 243
# Name: 209, dtype: object
# fname    2009_003042.jpg
# xmin                  84
# ymin                 180
# xmax                 139
# ymax                 249
# Name: 210, dtype: object
# fname    2009_003075.jpg
# xmin                 287
# ymin                 120
# xmax                 434
# ymax                 270
# Name: 211, dtype: object
# fname    2009_003075.jpg
# xmin                  69
# ymin                 124
# xmax                 299
# ymax                 323
# Name: 212, dtype: object
# fname    2009_003164.jpg
# xmin                 220
# ymin                 115
# xmax                 489
# ymax                 295
# Name: 213, dtype: object
# fname    2009_003164.jpg
# xmin                  69
# ymin                 122
# xmax                 222
# ymax                 255
# Name: 214, dtype: object
# fname    2009_003175.jpg
# xmin                   1
# ymin                  84
# xmax                 281
# ymax                 313
# Name: 215, dtype: object
# fname    2009_003175.jpg
# xmin                   4
# ymin                  96
# xmax                 246
# ymax                 262
# Name: 216, dtype: object
# fname    2009_003175.jpg
# xmin                 264
# ymin                  78
# xmax                 432
# ymax                 274
# Name: 217, dtype: object
# fname    2009_003175.jpg
# xmin                 302
# ymin                  91
# xmax                 500
# ymax                 249
# Name: 218, dtype: object
# fname    2009_003187.jpg
# xmin                  57
# ymin                   5
# xmax                 423
# ymax                 371
# Name: 219, dtype: object
# fname    2009_003353.jpg
# xmin                   1
# ymin                 238
# xmax                 239
# ymax                 375
# Name: 220, dtype: object
# fname    2009_003353.jpg
# xmin                 189
# ymin                 202
# xmax                 418
# ymax                 375
# Name: 221, dtype: object
# fname    2009_003381.jpg
# xmin                  19
# ymin                  24
# xmax                 472
# ymax                 316
# Name: 222, dtype: object
# fname    2009_003519.jpg
# xmin                  74
# ymin                  66
# xmax                 422
# ymax                 375
# Name: 223, dtype: object
# fname    2009_003644.jpg
# xmin                  28
# ymin                   1
# xmax                 500
# ymax                 375
# Name: 224, dtype: object
# fname    2009_003646.jpg
# xmin                 274
# ymin                 220
# xmax                 358
# ymax                 338
# Name: 225, dtype: object
# fname    2009_003646.jpg
# xmin                 335
# ymin                 337
# xmax                 500
# ymax                 375
# Name: 226, dtype: object
# fname    2009_003860.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 375
# Name: 227, dtype: object
# fname    2009_004069.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 320
# Name: 228, dtype: object
# fname    2009_004121.jpg
# xmin                  83
# ymin                  31
# xmax                 407
# ymax                 272
# Name: 229, dtype: object
# fname    2009_004340.jpg
# xmin                   1
# ymin                  96
# xmax                  53
# ymax                 207
# Name: 230, dtype: object
# fname    2009_004444.jpg
# xmin                  26
# ymin                 220
# xmax                 399
# ymax                 440
# Name: 231, dtype: object
# fname    2009_004508.jpg
# xmin                 270
# ymin                 186
# xmax                 338
# ymax                 314
# Name: 232, dtype: object
# fname    2009_004508.jpg
# xmin                 200
# ymin                 163
# xmax                 256
# ymax                 280
# Name: 233, dtype: object
# fname    2009_004508.jpg
# xmin                 183
# ymin                 165
# xmax                 208
# ymax                 248
# Name: 234, dtype: object
# fname    2009_004561.jpg
# xmin                 176
# ymin                 150
# xmax                 488
# ymax                 345
# Name: 235, dtype: object
# fname    2009_004571.jpg
# xmin                   4
# ymin                  44
# xmax                 373
# ymax                 497
# Name: 236, dtype: object
# fname    2009_004642.jpg
# xmin                  34
# ymin                 109
# xmax                 348
# ymax                 435
# Name: 237, dtype: object
# fname    2009_004710.jpg
# xmin                 134
# ymin                 279
# xmax                 159
# ymax                 364
# Name: 238, dtype: object
# fname    2009_004731.jpg
# xmin                  33
# ymin                 126
# xmax                 315
# ymax                 264
# Name: 239, dtype: object
# fname    2009_004797.jpg
# xmin                  50
# ymin                  15
# xmax                 473
# ymax                 369
# Name: 240, dtype: object
# fname    2009_004831.jpg
# xmin                 137
# ymin                 267
# xmax                 337
# ymax                 500
# Name: 241, dtype: object
# fname    2009_004831.jpg
# xmin                 289
# ymin                 162
# xmax                 320
# ymax                 206
# Name: 242, dtype: object
# fname    2009_004905.jpg
# xmin                   1
# ymin                 155
# xmax                 186
# ymax                 375
# Name: 243, dtype: object
# fname    2009_004914.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 375
# Name: 244, dtype: object
# fname    2009_004972.jpg
# xmin                  54
# ymin                  39
# xmax                 471
# ymax                 336
# Name: 245, dtype: object
# fname    2009_004984.jpg
# xmin                  46
# ymin                  52
# xmax                 462
# ymax                 329
# Name: 246, dtype: object
# fname    2009_005144.jpg
# xmin                   1
# ymin                   1
# xmax                 499
# ymax                 334
# Name: 247, dtype: object
# fname    2009_005154.jpg
# xmin                  29
# ymin                   4
# xmax                 433
# ymax                 322
# Name: 248, dtype: object
# fname    2009_005265.jpg
# xmin                 131
# ymin                 180
# xmax                 375
# ymax                 354
# Name: 249, dtype: object
# fname    2010_000056.jpg
# xmin                  50
# ymin                  73
# xmax                 457
# ymax                 268
# Name: 250, dtype: object
# fname    2010_000209.jpg
# xmin                  61
# ymin                  59
# xmax                 473
# ymax                 313
# Name: 251, dtype: object
# fname    2010_000356.jpg
# xmin                 133
# ymin                   1
# xmax                 500
# ymax                 371
# Name: 252, dtype: object
# fname    2010_000557.jpg
# xmin                  37
# ymin                  24
# xmax                 470
# ymax                 315
# Name: 253, dtype: object
# fname    2010_000571.jpg
# xmin                 154
# ymin                  31
# xmax                 359
# ymax                 170
# Name: 254, dtype: object
# fname    2010_000632.jpg
# xmin                 142
# ymin                  83
# xmax                 218
# ymax                 207
# Name: 255, dtype: object
# fname    2010_000685.jpg
# xmin                  89
# ymin                  47
# xmax                 456
# ymax                 339
# Name: 256, dtype: object
# fname    2010_000747.jpg
# xmin                   5
# ymin                 133
# xmax                 205
# ymax                 312
# Name: 257, dtype: object
# fname    2010_000910.jpg
# xmin                 233
# ymin                 203
# xmax                 375
# ymax                 373
# Name: 258, dtype: object
# fname    2010_001183.jpg
# xmin                  89
# ymin                  11
# xmax                 449
# ymax                 322
# Name: 259, dtype: object
# fname    2010_001254.jpg
# xmin                 291
# ymin                 169
# xmax                 389
# ymax                 245
# Name: 260, dtype: object
# fname    2010_001312.jpg
# xmin                 184
# ymin                 134
# xmax                 284
# ymax                 223
# Name: 261, dtype: object
# fname    2010_001338.jpg
# xmin                 240
# ymin                 226
# xmax                 500
# ymax                 374
# Name: 262, dtype: object
# fname    2010_001338.jpg
# xmin                 354
# ymin                 237
# xmax                 500
# ymax                 374
# Name: 263, dtype: object
# fname    2010_001338.jpg
# xmin                  14
# ymin                 277
# xmax                 362
# ymax                 375
# Name: 264, dtype: object
# fname    2010_001338.jpg
# xmin                   1
# ymin                 212
# xmax                 149
# ymax                 375
# Name: 265, dtype: object
# fname    2010_001431.jpg
# xmin                  36
# ymin                 242
# xmax                 367
# ymax                 437
# Name: 266, dtype: object
# fname    2010_001514.jpg
# xmin                   2
# ymin                  17
# xmax                 479
# ymax                 391
# Name: 267, dtype: object
# fname    2010_001592.jpg
# xmin                  16
# ymin                  10
# xmax                 489
# ymax                 303
# Name: 268, dtype: object
# fname    2010_001753.jpg
# xmin                 118
# ymin                  28
# xmax                 393
# ymax                 490
# Name: 269, dtype: object
# fname    2010_001922.jpg
# xmin                 114
# ymin                  48
# xmax                 412
# ymax                 289
# Name: 270, dtype: object
# fname    2010_001922.jpg
# xmin                 180
# ymin                  62
# xmax                 418
# ymax                 289
# Name: 271, dtype: object
# fname    2010_001970.jpg
# xmin                  72
# ymin                 323
# xmax                 280
# ymax                 488
# Name: 272, dtype: object
# fname    2010_002055.jpg
# xmin                  37
# ymin                 120
# xmax                 375
# ymax                 500
# Name: 273, dtype: object
# fname    2010_002180.jpg
# xmin                  57
# ymin                 198
# xmax                 393
# ymax                 375
# Name: 274, dtype: object
# fname    2010_002435.jpg
# xmin                 237
# ymin                  26
# xmax                 317
# ymax                  71
# Name: 275, dtype: object
# fname    2010_002435.jpg
# xmin                 211
# ymin                  39
# xmax                 246
# ymax                  77
# Name: 276, dtype: object
# fname    2010_002475.jpg
# xmin                  11
# ymin                  34
# xmax                 461
# ymax                 359
# Name: 277, dtype: object
# fname    2010_002497.jpg
# xmin                 242
# ymin                 120
# xmax                 401
# ymax                 222
# Name: 278, dtype: object
# fname    2010_002656.jpg
# xmin                  79
# ymin                   1
# xmax                 375
# ymax                 252
# Name: 279, dtype: object
# fname    2010_002656.jpg
# xmin                   1
# ymin                   1
# xmax                 375
# ymax                 500
# Name: 280, dtype: object
# fname    2010_002708.jpg
# xmin                 136
# ymin                 186
# xmax                 253
# ymax                 273
# Name: 281, dtype: object
# fname    2010_002720.jpg
# xmin                 295
# ymin                 163
# xmax                 423
# ymax                 275
# Name: 282, dtype: object
# fname    2010_002720.jpg
# xmin                  83
# ymin                 109
# xmax                 195
# ymax                 212
# Name: 283, dtype: object
# fname    2010_002801.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 375
# Name: 284, dtype: object
# fname    2010_002820.jpg
# xmin                   1
# ymin                 272
# xmax                 184
# ymax                 409
# Name: 285, dtype: object
# fname    2010_002915.jpg
# xmin                 349
# ymin                 202
# xmax                 500
# ymax                 337
# Name: 286, dtype: object
# fname    2010_003062.jpg
# xmin                  79
# ymin                 149
# xmax                 401
# ymax                 337
# Name: 287, dtype: object
# fname    2010_003093.jpg
# xmin                 133
# ymin                 283
# xmax                 434
# ymax                 374
# Name: 288, dtype: object
# fname    2010_003115.jpg
# xmin                  60
# ymin                 188
# xmax                 252
# ymax                 356
# Name: 289, dtype: object
# fname    2010_003148.jpg
# xmin                 227
# ymin                 180
# xmax                 276
# ymax                 212
# Name: 290, dtype: object
# fname    2010_003264.jpg
# xmin                 465
# ymin                 289
# xmax                 500
# ymax                 339
# Name: 291, dtype: object
# fname    2010_003264.jpg
# xmin                 314
# ymin                 254
# xmax                 410
# ymax                 331
# Name: 292, dtype: object
# fname    2010_003350.jpg
# xmin                  11
# ymin                  18
# xmax                 481
# ymax                 276
# Name: 293, dtype: object
# fname    2010_003367.jpg
# xmin                 112
# ymin                  17
# xmax                 409
# ymax                 328
# Name: 294, dtype: object
# fname    2010_003671.jpg
# xmin                  61
# ymin                 275
# xmax                 190
# ymax                 418
# Name: 295, dtype: object
# fname    2010_003671.jpg
# xmin                 233
# ymin                 265
# xmax                 279
# ymax                 319
# Name: 296, dtype: object
# fname    2010_003689.jpg
# xmin                 143
# ymin                 323
# xmax                 294
# ymax                 418
# Name: 297, dtype: object
# fname    2010_003703.jpg
# xmin                 107
# ymin                 321
# xmax                 236
# ymax                 427
# Name: 298, dtype: object
# fname    2010_003799.jpg
# xmin                 111
# ymin                  13
# xmax                 442
# ymax                 365
# Name: 299, dtype: object
# fname    2010_003906.jpg
# xmin                  89
# ymin                 175
# xmax                 181
# ymax                 298
# Name: 300, dtype: object
# fname    2010_003906.jpg
# xmin                 192
# ymin                 171
# xmax                 293
# ymax                 282
# Name: 301, dtype: object
# fname    2010_003914.jpg
# xmin                 216
# ymin                 273
# xmax                 346
# ymax                 500
# Name: 302, dtype: object
# fname    2010_004069.jpg
# xmin                 151
# ymin                 127
# xmax                 342
# ymax                 305
# Name: 303, dtype: object
# fname    2010_004072.jpg
# xmin                  46
# ymin                 123
# xmax                 282
# ymax                 296
# Name: 304, dtype: object
# fname    2010_004154.jpg
# xmin                 215
# ymin                 190
# xmax                 360
# ymax                 335
# Name: 305, dtype: object
# fname    2010_004154.jpg
# xmin                 140
# ymin                 169
# xmax                 209
# ymax                 278
# Name: 306, dtype: object
# fname    2010_004307.jpg
# xmin                   1
# ymin                 241
# xmax                 335
# ymax                 497
# Name: 307, dtype: object
# fname    2010_004609.jpg
# xmin                   7
# ymin                  22
# xmax                 475
# ymax                 323
# Name: 308, dtype: object
# fname    2010_004831.jpg
# xmin                  39
# ymin                   8
# xmax                 460
# ymax                 338
# Name: 309, dtype: object
# fname    2010_004878.jpg
# xmin                   1
# ymin                 156
# xmax                 362
# ymax                 489
# Name: 310, dtype: object
# fname    2010_005093.jpg
# xmin                  20
# ymin                   3
# xmax                 490
# ymax                 323
# Name: 311, dtype: object
# fname    2010_005111.jpg
# xmin                  90
# ymin                 144
# xmax                 349
# ymax                 338
# Name: 312, dtype: object
# fname    2010_005211.jpg
# xmin                  31
# ymin                  40
# xmax                 482
# ymax                 322
# Name: 313, dtype: object
# fname    2010_005402.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 333
# Name: 314, dtype: object
# fname    2010_005616.jpg
# xmin                   8
# ymin                   1
# xmax                 375
# ymax                 471
# Name: 315, dtype: object
# fname    2010_005670.jpg
# xmin                  80
# ymin                 121
# xmax                 340
# ymax                 483
# Name: 316, dtype: object
# fname    2010_005670.jpg
# xmin                   1
# ymin                  66
# xmax                  91
# ymax                 353
# Name: 317, dtype: object
# fname    2010_005670.jpg
# xmin                  34
# ymin                   1
# xmax                 258
# ymax                 112
# Name: 318, dtype: object
# fname    2010_005782.jpg
# xmin                  11
# ymin                  76
# xmax                 459
# ymax                 331
# Name: 319, dtype: object
# fname    2010_005810.jpg
# xmin                 324
# ymin                 104
# xmax                 483
# ymax                 220
# Name: 320, dtype: object
# fname    2010_005840.jpg
# xmin                   1
# ymin                 260
# xmax                  28
# ymax                 375
# Name: 321, dtype: object
# fname    2010_005840.jpg
# xmin                  99
# ymin                 211
# xmax                 260
# ymax                 375
# Name: 322, dtype: object
# fname    2010_005840.jpg
# xmin                 185
# ymin                 221
# xmax                 358
# ymax                 375
# Name: 323, dtype: object
# fname    2010_005909.jpg
# xmin                  37
# ymin                  20
# xmax                 459
# ymax                 290
# Name: 324, dtype: object
# fname    2010_006063.jpg
# xmin                  90
# ymin                 177
# xmax                 305
# ymax                 345
# Name: 325, dtype: object
# fname    2011_000297.jpg
# xmin                   1
# ymin                   7
# xmax                 499
# ymax                 375
# Name: 326, dtype: object
# fname    2011_000376.jpg
# xmin                   1
# ymin                  14
# xmax                 347
# ymax                 296
# Name: 327, dtype: object
# fname    2011_000376.jpg
# xmin                 326
# ymin                  81
# xmax                 500
# ymax                 334
# Name: 328, dtype: object
# fname    2011_000376.jpg
# xmin                   1
# ymin                   1
# xmax                 171
# ymax                 141
# Name: 329, dtype: object
# fname    2011_000376.jpg
# xmin                   1
# ymin                   4
# xmax                  76
# ymax                 104
# Name: 330, dtype: object
# fname    2011_000453.jpg
# xmin                 101
# ymin                  83
# xmax                 390
# ymax                 301
# Name: 331, dtype: object
# fname    2011_000453.jpg
# xmin                 381
# ymin                   1
# xmax                 471
# ymax                  44
# Name: 332, dtype: object
# fname    2011_000465.jpg
# xmin                  95
# ymin                 271
# xmax                 278
# ymax                 391
# Name: 333, dtype: object
# fname    2011_000485.jpg
# xmin                   1
# ymin                 118
# xmax                 500
# ymax                 333
# Name: 334, dtype: object
# fname    2011_000505.jpg
# xmin                  55
# ymin                 193
# xmax                 266
# ymax                 323
# Name: 335, dtype: object
# fname    2011_000579.jpg
# xmin                  52
# ymin                   1
# xmax                 499
# ymax                 375
# Name: 336, dtype: object
# fname    2011_000791.jpg
# xmin                   1
# ymin                   1
# xmax                 500
# ymax                 312
# Name: 337, dtype: object
# fname    2011_001028.jpg
# xmin                  99
# ymin                 185
# xmax                 372
# ymax                 495
# Name: 338, dtype: object
# fname    2011_001030.jpg
# xmin                 237
# ymin                 300
# xmax                 375
# ymax                 500
# Name: 339, dtype: object
# fname    2011_001030.jpg
# xmin                 178
# ymin                 253
# xmax                 200
# ymax                 271
# Name: 340, dtype: object
# fname    2011_001030.jpg
# xmin                 147
# ymin                 252
# xmax                 169
# ymax                 272
# Name: 341, dtype: object
# fname    2011_001153.jpg
# xmin                  88
# ymin                 324
# xmax                 224
# ymax                 408
# Name: 342, dtype: object
# fname    2011_001153.jpg
# xmin                   8
# ymin                 309
# xmax                  20
# ymax                 340
# Name: 343, dtype: object
# fname    2011_001153.jpg
# xmin                  18
# ymin                 312
# xmax                  37
# ymax                 335
# Name: 344, dtype: object
# fname    2011_001153.jpg
# xmin                  34
# ymin                 314
# xmax                  47
# ymax                 342
# Name: 345, dtype: object
# fname    2011_001153.jpg
# xmin                  41
# ymin                 308
# xmax                  60
# ymax                 340
# Name: 346, dtype: object
# fname    2011_001153.jpg
# xmin                 179
# ymin                 307
# xmax                 192
# ymax                 338
# Name: 347, dtype: object
# fname    2011_001422.jpg
# xmin                 158
# ymin                 238
# xmax                 311
# ymax                 375
# Name: 348, dtype: object
# fname    2011_001510.jpg
# xmin                 137
# ymin                 120
# xmax                 181
# ymax                 147
# Name: 349, dtype: object
# fname    2011_001538.jpg
# xmin                 426
# ymin                 162
# xmax                 500
# ymax                 275
# Name: 350, dtype: object
# fname    2011_001599.jpg
# xmin                   1
# ymin                   2
# xmax                 499
# ymax                 179
# Name: 351, dtype: object
# fname    2011_001632.jpg
# xmin                   1
# ymin                 201
# xmax                 494
# ymax                 375
# Name: 352, dtype: object
# fname    2011_001643.jpg
# xmin                  16
# ymin                  35
# xmax                 496
# ymax                 325
# Name: 353, dtype: object
# fname    2011_001732.jpg
# xmin                  10
# ymin                 207
# xmax                 290
# ymax                 500
# Name: 354, dtype: object
# fname    2011_001896.jpg
# xmin                 232
# ymin                 174
# xmax                 388
# ymax                 326
# Name: 355, dtype: object
# fname    2011_001937.jpg
# xmin                 408
# ymin                 143
# xmax                 494
# ymax                 205
# Name: 356, dtype: object
# fname    2011_001937.jpg
# xmin                 299
# ymin                 148
# xmax                 402
# ymax                 209
# Name: 357, dtype: object
# fname    2011_001937.jpg
# xmin                 205
# ymin                 143
# xmax                 290
# ymax                 216
# Name: 358, dtype: object
# fname    2011_001937.jpg
# xmin                  90
# ymin                 155
# xmax                 165
# ymax                 206
# Name: 359, dtype: object
# fname    2011_001937.jpg
# xmin                  95
# ymin                 164
# xmax                 177
# ymax                 229
# Name: 360, dtype: object
# fname    2011_001937.jpg
# xmin                 149
# ymin                 197
# xmax                 263
# ymax                 286
# Name: 361, dtype: object
# fname    2011_001937.jpg
# xmin                  62
# ymin                 185
# xmax                 115
# ymax                 257
# Name: 362, dtype: object
# fname    2011_001937.jpg
# xmin                  95
# ymin                 165
# xmax                 166
# ymax                 227
# Name: 363, dtype: object
# fname    2011_001937.jpg
# xmin                  63
# ymin                 166
# xmax                 102
# ymax                 227
# Name: 364, dtype: object
# fname    2011_001937.jpg
# xmin                  60
# ymin                 181
# xmax                 111
# ymax                 258
# Name: 365, dtype: object
# fname    2011_001949.jpg
# xmin                   1
# ymin                 237
# xmax                  35
# ymax                 264
# Name: 366, dtype: object
# fname    2011_001987.jpg
# xmin                 220
# ymin                 194
# xmax                 352
# ymax                 276
# Name: 367, dtype: object
# fname    2011_002006.jpg
# xmin                  69
# ymin                 169
# xmax                 407
# ymax                 375
# Name: 368, dtype: object
# fname    2011_002049.jpg
# xmin                 143
# ymin                 338
# xmax                 294
# ymax                 441
# Name: 369, dtype: object
# fname    2011_002049.jpg
# xmin                 101
# ymin                 383
# xmax                 215
# ymax                 424
# Name: 370, dtype: object
# fname    2011_002111.jpg
# xmin                  53
# ymin                 103
# xmax                 289
# ymax                 319
# Name: 371, dtype: object
# fname    2011_002111.jpg
# xmin                 304
# ymin                  51
# xmax                 338
# ymax                 111
# Name: 372, dtype: object
# fname    2011_002113.jpg
# xmin                   1
# ymin                 208
# xmax                 456
# ymax                 375
# Name: 373, dtype: object
# fname    2011_002135.jpg
# xmin                  35
# ymin                 274
# xmax                 466
# ymax                 500
# Name: 374, dtype: object
# fname    2011_002135.jpg
# xmin                 161
# ymin                   1
# xmax                 253
# ymax                  41
# Name: 375, dtype: object
# fname    2011_002281.jpg
# xmin                 298
# ymin                 218
# xmax                 432
# ymax                 434
# Name: 376, dtype: object
# fname    2011_002388.jpg
# xmin                 353
# ymin                 109
# xmax                 456
# ymax                 230
# Name: 377, dtype: object
# fname    2011_002455.jpg
# xmin                  45
# ymin                 216
# xmax                 187
# ymax                 486
# Name: 378, dtype: object
# fname    2011_002543.jpg
# xmin                 180
# ymin                 147
# xmax                 304
# ymax                 255
# Name: 379, dtype: object
# fname    2011_002585.jpg
# xmin                  88
# ymin                  53
# xmax                 193
# ymax                 160
# Name: 380, dtype: object
# fname    2011_002656.jpg
# xmin                 347
# ymin                 162
# xmax                 448
# ymax                 272
# Name: 381, dtype: object
# fname    2011_002656.jpg
# xmin                 368
# ymin                 173
# xmax                 448
# ymax                 284
# Name: 382, dtype: object
# fname    2011_002657.jpg
# xmin                  74
# ymin                 152
# xmax                 386
# ymax                 339
# Name: 383, dtype: object
# fname    2011_002811.jpg
# xmin                  53
# ymin                 152
# xmax                 257
# ymax                 431
# Name: 384, dtype: object
# fname    2011_002913.jpg
# xmin                  18
# ymin                   1
# xmax                 368
# ymax                 333
# Name: 385, dtype: object
# fname    2011_002958.jpg
# xmin                  43
# ymin                  87
# xmax                 133
# ymax                 279
# Name: 386, dtype: object
# fname    2011_003054.jpg
# xmin                 462
# ymin                 257
# xmax                 500
# ymax                 314
# Name: 387, dtype: object
# fname    2011_003054.jpg
# xmin                 256
# ymin                 271
# xmax                 279
# ymax                 300
# Name: 388, dtype: object
# fname    2011_003054.jpg
# xmin                 410
# ymin                 262
# xmax                 429
# ymax                 295
# Name: 389, dtype: object
# fname    2011_003063.jpg
# xmin                   1
# ymin                   1
# xmax                 149
# ymax                 181
# Name: 390, dtype: object
# fname    2011_003148.jpg
# xmin                 112
# ymin                  16
# xmax                 403
# ymax                 343
# Name: 391, dtype: object
# fname    2011_003148.jpg
# xmin                 368
# ymin                   1
# xmax                 452
# ymax                  32
# Name: 392, dtype: object
#                fname  xmin  ymin  xmax  ymax
# 0    2008_000036.jpg   120     1   203    35
# 1    2008_000036.jpg   117    38   273   121
# 2    2008_000191.jpg    57   194   151   255
# 3    2008_000196.jpg   348     7   500   309
# 4    2008_000196.jpg     1     1   206   310
# 5    2008_000531.jpg    99   183   203   263
# 6    2008_000615.jpg    50   179   311   375
# 7    2008_000764.jpg    39   331   243   487
# 8    2008_001336.jpg     1     1   500   372
# 9    2008_001375.jpg   275   249   500   333
# 10   2008_001375.jpg     1   290   198   333
# 11   2008_001402.jpg   115   279   243   482
# 12   2008_001523.jpg   115   244   214   349
# 13   2008_001566.jpg     1   190   149   300
# 14   2008_001626.jpg    20    11   439   375
# 15   2008_001791.jpg    45   393   112   500
# 16   2008_001813.jpg     1    35   334   500
# 17   2008_001860.jpg     1   201   151   333
# 18   2008_001986.jpg    49   241   286   379
# 19   2008_002129.jpg     6     1   432   319
# 20   2008_002204.jpg   117   243   247   322
# 21   2008_002370.jpg     1     1    81   240
# 22   2008_002418.jpg    40   201   309   475
# 23   2008_002515.jpg     1     1   500   334
# 24   2008_002679.jpg    94   103   239   306
# 25   2008_002787.jpg    35   170   231   375
# 26   2008_002787.jpg   296   176   500   375
# 27   2008_002880.jpg   151   245   254   301
# 28   2008_002894.jpg    43   154   388   332
# 29   2008_002948.jpg     9     1   169   333
# ..               ...   ...   ...   ...   ...
# 363  2011_001937.jpg    95   165   166   227
# 364  2011_001937.jpg    63   166   102   227
# 365  2011_001937.jpg    60   181   111   258
# 366  2011_001949.jpg     1   237    35   264
# 367  2011_001987.jpg   220   194   352   276
# 368  2011_002006.jpg    69   169   407   375
# 369  2011_002049.jpg   143   338   294   441
# 370  2011_002049.jpg   101   383   215   424
# 371  2011_002111.jpg    53   103   289   319
# 372  2011_002111.jpg   304    51   338   111
# 373  2011_002113.jpg     1   208   456   375
# 374  2011_002135.jpg    35   274   466   500
# 375  2011_002135.jpg   161     1   253    41
# 376  2011_002281.jpg   298   218   432   434
# 377  2011_002388.jpg   353   109   456   230
# 378  2011_002455.jpg    45   216   187   486
# 379  2011_002543.jpg   180   147   304   255
# 380  2011_002585.jpg    88    53   193   160
# 381  2011_002656.jpg   347   162   448   272
# 382  2011_002656.jpg   368   173   448   284
# 383  2011_002657.jpg    74   152   386   339
# 384  2011_002811.jpg    53   152   257   431
# 385  2011_002913.jpg    18     1   368   333
# 386  2011_002958.jpg    43    87   133   279
# 387  2011_003054.jpg   462   257   500   314
# 388  2011_003054.jpg   256   271   279   300
# 389  2011_003054.jpg   410   262   429   295
# 390  2011_003063.jpg     1     1   149   181
# 391  2011_003148.jpg   112    16   403   343
# 392  2011_003148.jpg   368     1   452    32
#
# [393 rows x 5 columns]
